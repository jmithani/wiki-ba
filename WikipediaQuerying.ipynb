# %%
import pandas as pd

data = pd.read_csv("data/processed_recs2.csv")
df = pd.DataFrame(data=data)
df.head()
# Out:
#    Unnamed: 0                                                 AB  \
# 0           0  General strategies for the chemical synthesis ...
# 1           1  Ancient DNA makes it possible to observe natur...
# 2           2  Nitrification, the oxidation of ammonia via ni...
# 3           3  Deletion of phenylalanine 508 of the cystic fi...
# 4           4  T helper 17 (T(H)17) lymphocytes protect mucos...
#
#                                                   AF  AR  \
# 0  Marth, C. J.; Gallego, G. M.; Lee, J. C.; Lebo... NaN
# 1  Mathieson, Iain; Lazaridis, Iosif; Rohland, Na... NaN
# 2  Daims, Holger; Lebedeva, Elena V.; Pjevac, Pet... NaN
# 3  Pankow, Sandra; Bamberger, Casimir; Calzolari,... NaN
# 4  Huang, Wendy; Thomas, Benjamin; Flynn, Ryan A.... NaN
#
#                                                   AU  BA  BE  BF  BN   BP  \
# 0  Marth, CJ; Gallego, GM; Lee, JC; Lebold, TP; K... NaN NaN NaN NaN  493
# 1  Mathieson, I; Lazaridis, I; Rohland, N; Mallic... NaN NaN NaN NaN  499
# ...

# %%
df = df.loc[~(df["scholar_id"] == "na")]
df
# Out:
#      Unnamed: 0                                                 AB  \
# 1             1  Ancient DNA makes it possible to observe natur...
# 2             2  Nitrification, the oxidation of ammonia via ni...
# 13           13  Nitrification is a two-step process where ammo...
# 17           17  Eukaryotic transcription factors (TFs) are key...
# 18           18  A central question in protein evolution is the...
# 19           19  Tandem repeat proteins, which are formed by re...
# 24           24  Magnetohydrodynamic turbulence is important in...
# 27           27  Radiative transfer of energy at the nanometre ...
# 35           35  DNA repair by homologous recombination(1) is h...
# 47           47  In recent years, several associations between ...
# 49           49  Skeletal growth relies on both biosynthetic an...
# 51           51  During asymmetric division, fate determinants ...
# 54           54  The exchange of nutrients, energy and carbon b...
# ...

# %%
len(df.index)
# Out:
# 119
